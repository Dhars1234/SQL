# %%
# %load_ext sql

# %%
# %sql mysql+mysqldb://root:Mysql&12345@localhost/projects_hr
# Out:
# 'Connected: root@projects_hr'

# %%
# %sql select * from hr LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 5 rows affected.
# [('00-0037846', 'Kimmy', 'Walczynski', datetime.date(1991, 6, 4), 'Male', 'Hispanic or Latino', 'Engineering', 'Programmer Analyst I', 'Headquarters', datetime.date(2002, 1, 20), None, 'Cleveland', 'Ohio', 32),
#  ('00-0041533', 'Ignatius', 'Springett', datetime.date(1984, 6, 29), 'Male', 'White', 'Business Development', 'Business Analyst', 'Headquarters', datetime.date(2019, 8, 4), None, 'Cleveland', 'Ohio', 39),
#  ('00-0045747', 'Corbie', 'Bittlestone', datetime.date(1989, 7, 29), 'Male', 'Black or African American', 'Sales', 'Solutions Engineer Manager', 'Headquarters', datetime.date(2010, 12, 10), None, 'Cleveland', 'Ohio', 34),
#  ('00-0055274', 'Baxy', 'Matton', datetime.date(1982, 9, 14), 'Female', 'White', 'Services', 'Service Tech', 'Headquarters', datetime.date(2005, 10, 4), None, 'Cleveland', 'Ohio', 41),
# ...

# %% [markdown]
# 1. What is the gender breakdown of employees in the company?

# %%
# %%sql
# SELECT gender, COUNT(*) AS count
# FROM hr
# WHERE age >= 18
# GROUP BY gender
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 3 rows affected.
# [('Male', 10794), ('Female', 9876), ('Non-Conforming', 577)]

# %%
2. What is the race/ethnicity breakdown of employees in the company?
# Out:
# Object `company` not found.

# %%
# %%sql
# SELECT race, COUNT(*) AS count
# FROM hr
# WHERE age >= 18
# GROUP BY race
# ORDER BY count DESC
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 7 rows affected.
# [('White', 6057),
#  ('Two or More Races', 3508),
#  ('Black or African American', 3443),
#  ('Asian', 3388),
#  ('Hispanic or Latino', 2402),
#  ('American Indian or Alaska Native', 1273),
#  ('Native Hawaiian or Other Pacific Islander', 1176)]

# %% [markdown]
# 3. What is the age distribution of employees in the company?

# %%
# %%sql
# SELECT
#   MIN(age) AS youngest,
#   MAX(age) AS oldest
# FROM hr
# WHERE age >= 18
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 1 rows affected.
# [(21, 57)]

# %%
# %%sql
# SELECT
#   CASE
#     WHEN age >= 18 AND age <= 24 THEN '18-24'
#     WHEN age >= 25 AND age <= 34 THEN '25-34'
#     WHEN age >= 35 AND age <= 44 THEN '35-44'
#     WHEN age >= 45 AND age <= 54 THEN '45-54'
#     WHEN age >= 55 AND age <= 64 THEN '55-64'
#     ELSE '65+'
#   END AS age_group, gender,
#   COUNT(*) AS count
# FROM
#   hr
# WHERE
#   age >= 18
# GROUP BY age_group, gender
# ORDER BY age_group, gender;
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 15 rows affected.
# [('18-24', 'Female', 1090),
#  ('18-24', 'Male', 1272),
#  ('18-24', 'Non-Conforming', 61),
#  ('25-34', 'Female', 2860),
#  ('25-34', 'Male', 3038),
#  ('25-34', 'Non-Conforming', 156),
#  ('35-44', 'Female', 2719),
#  ('35-44', 'Male', 3154),
#  ('35-44', 'Non-Conforming', 166),
#  ('45-54', 'Female', 2696),
#  ('45-54', 'Male', 2829),
#  ('45-54', 'Non-Conforming', 158),
#  ('55-64', 'Female', 511),
#  ('55-64', 'Male', 501),
#  ('55-64', 'Non-Conforming', 36)]

# %% [markdown]
#  4. How many employees work at headquarters versus remote locations?

# %%
# %%sql
# SELECT location, COUNT(*) as count
# FROM hr
# WHERE age >= 18
# GROUP BY location;
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 2 rows affected.
# [('Headquarters', 15992), ('Remote', 5255)]

# %% [markdown]
# 5. What is the average length of employment for employees who have been terminated?

# %%
# %%sql
# Select round(avg(timestampdiff(year,hire_date,termdate))) as avg_len_emp
# from hr
# where termdate <> 0000-00-00 and age >=18 and termdate<=curdate()
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 1 rows affected.
# [(Decimal('7'),)]

# %% [markdown]
# 6. How does the gender distribution vary across departments?

# %%
# %%sql
# SELECT department, gender, COUNT(*) as count
# FROM hr
# WHERE age >= 18
# GROUP BY department, gender
# ORDER BY department;
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 38 rows affected.
# [('Accounting', 'Female', 1462),
#  ('Accounting', 'Male', 1640),
#  ('Accounting', 'Non-Conforming', 90),
#  ('Auditing', 'Female', 23),
#  ('Auditing', 'Male', 27),
#  ('Business Development', 'Female', 722),
#  ('Business Development', 'Male', 798),
#  ('Business Development', 'Non-Conforming', 49),
#  ('Engineering', 'Female', 2983),
#  ('Engineering', 'Male', 3225),
#  ('Engineering', 'Non-Conforming', 179),
#  ('Human Resources', 'Female', 820),
#  ('Human Resources', 'Male', 867),
#  ('Human Resources', 'Non-Conforming', 40),
#  ('Legal', 'Female', 134),
#  ('Legal', 'Male', 158),
#  ('Legal', 'Non-Conforming', 7),
#  ('Marketing', 'Female', 230),
#  ('Marketing', 'Male', 245),
#  ('Marketing', 'Non-Conforming', 5),
#  ('Product Management', 'Female', 270),
#  ('Product Management', 'Male', 338),
#  ('Product Management', 'Non-Conforming', 15),
#  ('Research and Development', 'Female', 491),
# ...

# %% [markdown]
# 7. What is the distribution of job titles across the company?

# %%
# %%sql
# SELECT jobtitle, COUNT(*) as count
# FROM hr
# WHERE age >= 18
# GROUP BY jobtitle
# ORDER BY jobtitle DESC;
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 185 rows affected.
# [('Web Developer IV', 66),
#  ('Web Developer III', 69),
#  ('Web Developer II', 74),
#  ('Web Developer I', 95),
#  ('Web Designer IV', 6),
#  ('Web Designer III', 13),
#  ('Web Designer II', 4),
#  ('Web Designer I', 34),
#  ('VP Sales', 5),
#  ('VP Quality Control', 43),
#  ('VP Product Management', 39),
#  ('VP of Training and Development', 1),
#  ('VP Marketing', 42),
#  ('VP Accounting', 76),
#  ('Training Manager', 177),
#  ('Trainer III', 173),
#  ('Trainer II', 175),
#  ('Trainer I', 171),
#  ('Tax Accountant', 294),
#  ('Systems Administrator IV', 84),
#  ('Systems Administrator III', 81),
#  ('Systems Administrator II', 66),
#  ('Systems Administrator I', 359),
#  ('Support Staff III', 19),
#  ('Support Staff II', 58),
#  ('Support Staff', 94),
#  ('Structural Engineer', 293),
#  ('Structural Analysis Engineer', 45),
#  ('Statistician IV', 2),
#  ('Statistician III', 4),
#  ('Statistician II', 11),
# ...

# %% [markdown]
# 8. Which department has the highest turnover rate?

# %%
# %%sql
# select department,count(*) as total_count,
# sum(case when termdate <= curdate() and termdate <> 0000-00-00 then 1 else 0 end) as terminated_count,
# sum(case when termdate <= curdate() and termdate = 0000-00-00 then 1 else 0 end) as active_count,
# (sum(case when termdate <= curdate()  then 1 else 0 end)/ count(*))as termination_rate
# from hr
# where age>=18
# group by department
# ORDER BY termination_rate DESC;
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 13 rows affected.
# [('Marketing', 480, Decimal('43'), Decimal('410'), Decimal('0.9438')),
#  ('Training', 1622, Decimal('189'), Decimal('1338'), Decimal('0.9414')),
#  ('Human Resources', 1727, Decimal('190'), Decimal('1430'), Decimal('0.9380')),
#  ('Accounting', 3192, Decimal('352'), Decimal('2626'), Decimal('0.9330')),
#  ('Services', 1618, Decimal('172'), Decimal('1337'), Decimal('0.9326')),
#  ('Engineering', 6387, Decimal('696'), Decimal('5259'), Decimal('0.9324')),
#  ('Product Management', 623, Decimal('66'), Decimal('512'), Decimal('0.9278')),
#  ('Business Development', 1569, Decimal('147'), Decimal('1307'), Decimal('0.9267')),
#  ('Sales', 1745, Decimal('190'), Decimal('1426'), Decimal('0.9261')),
#  ('Legal', 299, Decimal('39'), Decimal('237'), Decimal('0.9231')),
#  ('Auditing', 50, Decimal('8'), Decimal('38'), Decimal('0.9200')),
# ...

# %% [markdown]
# 9. What is the distribution of employees across locations by state?

# %%
# %%sql
# SELECT location_state, COUNT(*) as count
# FROM hr
# WHERE age >= 18
# GROUP BY location_state
# ORDER BY count DESC;
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 7 rows affected.
# [('Ohio', 17252),
#  ('Pennsylvania', 1066),
#  ('Illinois', 833),
#  ('Indiana', 666),
#  ('Michigan', 650),
#  ('Kentucky', 417),
#  ('Wisconsin', 363)]

# %% [markdown]
# 10. How has the company's employee count changed over time based on hire and term dates?
# This query groups the employees by the year of their hire date and calculates the total number of hires, terminations, and net change (the difference between hires and terminations) for each year. The results are sorted by year in ascending order.

# %%
# %%sql
# Select year, hires,terminations,
# ((hires)-(terminations)) as net_change,
# ROUND(((hires - terminations) / hires * 100), 2) AS net_change_percent
# from (
# select
# year(hire_date) as year, count(hire_date) as hires, sum( case when termdate<=curdate() and termdate <> 0000-00-00 then 1 else 0 end) as terminations
# from hr
# where age >=18
# group by year(hire_date)
# ) subquery
# order by hires
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 21 rows affected.
# [(2000, 211, Decimal('26'), Decimal('185'), Decimal('87.68')),
#  (2020, 967, Decimal('22'), Decimal('945'), Decimal('97.72')),
#  (2015, 1011, Decimal('69'), Decimal('942'), Decimal('93.18')),
#  (2002, 1012, Decimal('161'), Decimal('851'), Decimal('84.09')),
#  (2014, 1014, Decimal('81'), Decimal('933'), Decimal('92.01')),
#  (2019, 1038, Decimal('45'), Decimal('993'), Decimal('95.66')),
#  (2005, 1038, Decimal('166'), Decimal('872'), Decimal('84.01')),
#  (2013, 1042, Decimal('89'), Decimal('953'), Decimal('91.46')),
#  (2017, 1043, Decimal('49'), Decimal('994'), Decimal('95.30')),
#  (2010, 1050, Decimal('119'), Decimal('931'), Decimal('88.67')),
#  (2011, 1057, Decimal('107'), Decimal('950'), Decimal('89.88')),
#  (2007, 1058, Decimal('139'), Decimal('919'), Decimal('86.86')),
#  (2012, 1059, Decimal('102'), Decimal('957'), Decimal('90.37')),
# ...

# %% [markdown]
# 11. What is the tenure distribution for each department?

# %%
# %%sql
# SELECT department, ROUND(AVG(DATEDIFF(CURDATE(), termdate)/365),0) as avg_tenure
# FROM hr
# WHERE termdate <= CURDATE() AND termdate <> 0000-00-00 AND age >= 18
# GROUP BY department
# Out:
#  * mysql+mysqldb://root:***@localhost/projects_hr
# 13 rows affected.
# [('Engineering', Decimal('8')),
#  ('Services', Decimal('8')),
#  ('Human Resources', Decimal('8')),
#  ('Business Development', Decimal('9')),
#  ('Sales', Decimal('8')),
#  ('Auditing', Decimal('9')),
#  ('Training', Decimal('8')),
#  ('Accounting', Decimal('8')),
#  ('Research and Development', Decimal('8')),
#  ('Product Management', Decimal('8')),
#  ('Support', Decimal('8')),
#  ('Legal', Decimal('9')),
#  ('Marketing', Decimal('7'))]
